# %%
import matplotlib.pyplot as plt
import seaborn as sns

from funcs import *

sns.set()
# Out:
# /Users/shionhonda/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
X, y = gen_data_colinear(f_rand, 100, 5)

plt.figure(figsize=(5, 5))
plt.scatter(X[:,3], X[:,4])
plt.xlabel(" Feature 3")
plt.ylabel("Feature 4")
plt.show()

# %%
def plot(imps, titles):
    fig = plt.figure(figsize=(12,12))
    for i in range(4):
        ax = fig.add_subplot(2, 2, i+1)
        sns.violinplot(data=imps[i])
        ax.set_xlabel("Feature", fontsize=12)
        ax.set_ylabel("Importance", fontsize=12)
        ax.set_title(f"{titles[i]} importance", fontsize=18)
    plt.show()

# %% [markdown]
# ## Random Target
# ### Control

# %%
n_train = 1000
n_val = 200
n_features = 5
n_iters = 100
titles = ["Gini", "Split", "Drop-column", "Permutation"]

imp_gini = gini_importance(gen_data_ctrl, f_rand, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_ctrl, f_rand, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_ctrl, f_rand, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_ctrl, f_rand, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:14<00:00,  7.07it/s]

# %% [markdown]
# ### Different Cardinality

# %%
imp_gini = gini_importance(gen_data_card, f_rand, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_card, f_rand, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_card, f_rand, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_card, f_rand, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:26<00:00,  3.73it/s]

# %% [markdown]
# ### Duplicated Column

# %%
imp_gini = gini_importance(gen_data_dup, f_rand, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_dup, f_rand, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_dup, f_rand, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_dup, f_rand, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:16<00:00,  6.07it/s]

# %% [markdown]
# ### Colinearity

# %%
imp_gini = gini_importance(gen_data_colinear, f_rand, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_colinear, f_rand, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_colinear, f_rand, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_colinear, f_rand, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:20<00:00,  4.95it/s]

# %% [markdown]
# ## Synthetic Target
# ### Control

# %%
imp_gini = gini_importance(gen_data_ctrl, f_noised_mean, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_ctrl, f_noised_mean, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_ctrl, f_noised_mean, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_ctrl, f_noised_mean, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:16<00:00,  6.05it/s]

# %% [markdown]
# ### Different Cardinality

# %%
imp_gini = gini_importance(gen_data_card, f_noised_mean, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_card, f_noised_mean, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_card, f_noised_mean, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_card, f_noised_mean, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:18<00:00,  5.34it/s]

# %% [markdown]
# ### Duplicated Columns

# %%
imp_gini = gini_importance(gen_data_dup, f_noised_mean, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_dup, f_noised_mean, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_dup, f_noised_mean, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_dup, f_noised_mean, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:18<00:00,  5.49it/s]

# %% [markdown]
# ### Colinearity

# %%
imp_gini = gini_importance(gen_data_colinear, f_noised_mean, n_iters, n_features, n_train)
imp_split = split_importance(gen_data_colinear, f_noised_mean, n_iters, n_features, n_train)
imp_drop = drop_importance(gen_data_colinear, f_noised_mean, n_iters, n_features, n_train, n_val)
imp_perm = perm_importance(gen_data_colinear, f_noised_mean, n_iters, n_features, n_train, n_val)
plot([imp_gini, imp_split, imp_drop, imp_perm], titles)
# Out:
# ...
# 100%|██████████| 100/100 [00:16<00:00,  6.20it/s]
